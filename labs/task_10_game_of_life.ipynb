# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## MPI version

# %%
# int ws = 100;
# int hs = 1000;

t = [
    np.array([0.679395, 0.666791, 0.672317, 0.660945, 0.659633, 0.661309, 0.665277, 0.664559, 0.674806]),
    np.array([0.342769, 0.343832, 0.341136, 0.340485, 0.334213, 0.333230, 0.335578, 0.358124, 0.349679]),
    np.array([0.228258, 0.227895, 0.243700, 0.225381, 0.225365, 0.227078, 0.227484, 0.226426, 0.223955]),
    np.array([0.296633, 0.309666, 0.266170, 0.174319, 0.203875, 0.177260, 0.197183, 0.193972, 0.171520]),
    np.array([0.237248, 0.206417, 0.141018, 0.142356, 0.142732, 0.142119, 0.143037, 0.142160, 0.141391]),
    np.array([0.157215, 0.120370, 0.120215, 0.124400, 0.122885, 0.124792, 0.123803, 0.123974, 0.123523]),
    np.array([0.183673, 0.151707, 0.180052, 0.209942, 0.188068, 0.187803, 0.187629, 0.189187, 0.188723]),
    np.array([0.162994, 0.168371, 0.168969, 0.167883, 0.167905, 0.168670, 0.169830, 0.170017, 0.170262]),
]
t = np.array([np.mean(q) for q in t])

print('S =', t[0]/t)
print('E =', t[0]/np.arange(1, len(t)+1)/t)
# Out:
# S = [1.         1.9502898  2.92138618 3.01669749 4.1745734  5.262139
#  3.60276557 3.96397652]
# E = [1.         0.9751449  0.97379539 0.75417437 0.83491468 0.87702317
#  0.5146808  0.49549707]

# %%
# int ws = 1000;
# int hs = 100;

t = [
    np.array([0.670496, 0.687879, 0.674294, 0.669161, 0.680107, 0.671513, 0.671205, 0.671154, 0.673710]),
    np.array([0.343749, 0.340125, 0.339652, 0.380152, 0.366815, 0.337403, 0.338090, 0.341757, 0.336730]),
    np.array([0.234322, 0.234223, 0.232745, 0.230811, 0.229267, 0.234041, 0.234842, 0.230430, 0.228796]),
    np.array([0.211975, 0.171908, 0.175223, 0.176483, 0.183701, 0.187703, 0.173483, 0.181362, 0.175588]),
    np.array([0.158713, 0.143549, 0.145879, 0.147407, 0.147639, 0.146746, 0.147924, 0.150127, 0.150702]),
    np.array([0.198505, 0.118481, 0.121605, 0.122141, 0.121236, 0.122352, 0.123079, 0.123007, 0.122460]),
    np.array([0.166494, 0.156202, 0.120577, 0.106846, 0.111637, 0.126145, 0.144492, 0.107411, 0.107968]),
    np.array([0.163442, 0.166108, 0.168236, 0.171388, 0.171186, 0.173964, 0.172782, 0.103974, 0.106304])
]
t = np.array([np.mean(q) for q in t])

print('S =', t[0]/t)
print('E =', t[0]/np.arange(1, len(t)+1)/t)
# Out:
# S = [1.         1.94257368 2.90480297 3.706744   4.53393776 5.17494667
#  5.2880877  4.34348683]
# E = [1.         0.97128684 0.96826766 0.926686   0.90678755 0.86249111
#  0.7554411  0.54293585]

# %%
# with noskip optimization
# int ws = 20;
# int hs = 10000000;
#without
time: 6.968816
time: 7.208358
time: 7.268070
time: 7.401295
time: 7.525567
time: 7.375780

# with 
time: 7.234585
time: 7.206144
time: 7.223356
time: 7.455992
time: 7.224838


# int ws = 200;
# int hs = 1000000;
#without
time: 8.196281
time: 8.197215
time: 8.048760
time: 8.158112
time: 8.664021
time: 8.622058

#with
time: 7.732676
time: 7.830277
time: 8.346199
time: 8.186401
time: 7.979212
time: 8.746173

print('S =', t[0]/t)
print('E =', t[0]/np.arange(1, len(t)+1)/t)
# Out:
# S = [1.         1.9872977  2.96921361 3.85657624 4.53419917 5.32989885
#  3.65828127 4.22532125]
# E = [1.         0.99364885 0.98973787 0.96414406 0.90683983 0.88831648
#  0.52261161 0.52816516]

# %% [markdown]
# ## Hybrid version

# %%
# int ws = 2000;
# int hs = 10000;

t = np.array([
    10 * 10 / 83 ,
    10 * 10 / 169,
    10 * 10 / 236,
    10 * 10 / 180,
])
print('S =', t[0]/t)
print('E =', t[0]/np.arange(1, len(t)+1)/t)
# Out:
# S = [1.         2.03614458 2.84337349 2.1686747 ]
# E = [1.         1.01807229 0.94779116 0.54216867]

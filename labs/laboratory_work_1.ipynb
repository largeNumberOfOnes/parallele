# %%
import matplotlib.pyplot as plt
plt.style.use('default')
import numpy as np

# %%
with open('../output/calc.txt') as file:
    lines = file.readlines()
    arr = list(map(lambda s: list(map(float, s[:-3].split(', '))), lines))
    plt.figure(figsize=(10, 7))
    plt.title("Solution")
    plt.xlabel("x")
    plt.ylabel("t")
    plt.pcolormesh(arr)
    plt.colorbar()

# %%
print(f"""\
1 proc -> {0.050511:.3}; S1 = {0.050511/0.050511:.2}; E1 = {0.050511/0.050511/1:.2};
2 proc -> {0.033175:.3}; S2 = {0.050511/0.033175:.2}; E2 = {0.050511/0.033175/2:.2};
4 proc -> {0.023887:.3}; S4 = {0.050511/0.023887:.2}; E4 = {0.050511/0.023887/4:.2};
5 proc -> {0.021114:.3}; S5 = {0.050511/0.021114:.2}; E5 = {0.050511/0.021114/5:.2};
8 proc -> {0.019697:.3}; S8 = {0.050511/0.019697:.2}; E8 = {0.050511/0.019697/8:.2};\
""")
# Out:
# 1 proc -> 0.0505; S1 = 1.0; E1 = 1.0;
# 2 proc -> 0.0332; S2 = 1.5; E2 = 0.76;
# 4 proc -> 0.0239; S4 = 2.1; E4 = 0.53;
# 5 proc -> 0.0211; S5 = 2.4; E5 = 0.48;
# 8 proc -> 0.0197; S8 = 2.6; E8 = 0.32;
